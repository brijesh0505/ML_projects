# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data.csv',header=None)

# %%
data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   0
# 1  0.0052  0.0044   0
# 2  0.0095  0.0078   0
# ...

# %%
data.shape
# Out:
# (208, 61)

# %%
data[60].value_counts()
# Out:
# 60
# 1    111
# 0     97
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.013420
# ...

# %%
data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# 0   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
# 1   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# 0   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
# 1   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
#
#           54        55        56        57        58        59
# 60
# 0   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
# 1   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
#
# [2 rows x 60 columns]

# %%
x=data.drop(columns = 60,axis = 1)
y = data[60]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1,test_size=0.1,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(x_train)
train_acc = accuracy_score(y_pred,y_train)

# %%
train_acc
# Out:
# 0.8342245989304813

# %%
y_pred = model.predict(x_test)
test_acc = accuracy_score(y_test,y_pred)

# %%
test_acc
# Out:
# 0.8095238095238095

# %%
input_data = [0.0283, 0.0599, 0.0656, 0.0229, 0.0839, 0.1673, 0.1154, 0.1098, 0.1370, 0.1767,
                     0.1995, 0.2869, 0.3275, 0.3769, 0.4169, 0.5036, 0.6180, 0.8025, 0.9333, 0.9399,
                     0.9275, 0.9450, 0.8328, 0.7773, 0.7007, 0.6154, 0.5810, 0.4454, 0.3707, 0.2891,
                     0.2185, 0.1711, 0.3578, 0.3947, 0.2867, 0.2401, 0.3619, 0.3314, 0.3763, 0.4767,
                     0.4059, 0.3661, 0.2320, 0.1450, 0.1017, 0.1111, 0.0655, 0.0271, 0.0244, 0.0179,
                     0.0109, 0.0147, 0.0170, 0.0158, 0.0046, 0.0073, 0.0054, 0.0033, 0.0045, 0.0079]
input_data_np = np.array(input_data).reshape(1, -1)
prediction = model.predict(input_data_np)
print("Predicted class:", prediction[0])
# 0 - ROCK | 1 - MINE
# Out:
# Predicted class: 1
